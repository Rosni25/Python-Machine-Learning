# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import joblib

# %%
data=pd.read_csv("C:\\Users\\User\\Downloads\\Life Expectancy Data v2.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy (men)            2938 non-null   int64
#  4   Life expectancy(women)           2938 non-null   int64
#  5   Adult Mortality (men)            2938 non-null   int64
#  6   Adult Mortality (women)          2938 non-null   int64
#  7   Infant deaths                    2938 non-null   int64
#  8   Alcohol                          2744 non-null   float64
#  9   Percentage expenditure           2938 non-null   float64
#  10  Hepatitis B(men)                 2938 non-null   int64
#  11  Hepatitis B(women)               2938 non-null   int64
# ...

# %%
data.count()
# Out:
# Country                            2938
# Year                               2938
# Status                             2938
# Life expectancy (men)              2938
# Life expectancy(women)             2938
# Adult Mortality (men)              2938
# Adult Mortality (women)            2938
# Infant deaths                      2938
# Alcohol                            2744
# Percentage expenditure             2938
# Hepatitis B(men)                   2938
# Hepatitis B(women)                 2938
# Measles                            2938
# BMI                                2904
# Under-five deaths                  2938
# Polio                              2919
# Total expenditure                  2712
# Diphtheria                         2919
# HIV/AIDS                           2938
# GDP                                2490
# Population                         2286
# thinness  1-19 years               2904
# thinness 5-9 years                 2904
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy (men)',
#        'Life expectancy(women)', 'Adult Mortality (men)',
#        'Adult Mortality (women)', 'Infant deaths', 'Alcohol',
#        'Percentage expenditure', 'Hepatitis B(men)', 'Hepatitis B(women)',
#        'Measles', 'BMI', 'Under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data.groupby('Alcohol')['Infant deaths'].max().tail(10)
# Out:
# Alcohol
# 15.04    0
# 15.07    0
# 15.14    0
# 15.19    0
# 15.52    0
# 16.35    0
# 16.58    0
# 16.99    0
# 17.31    0
# 17.87    0
# Name: Infant deaths, dtype: int64

# %%
data.groupby('Alcohol')['Infant deaths'].mean().tail(10)
# Out:
# Alcohol
# 15.04    0.0
# 15.07    0.0
# 15.14    0.0
# 15.19    0.0
# 15.52    0.0
# 16.35    0.0
# 16.58    0.0
# 16.99    0.0
# 17.31    0.0
# 17.87    0.0
# Name: Infant deaths, dtype: float64

# %%
#.Display top 5 Rows of the dataset
data.head(5)

# %%
#Check the last 3 rows of the dataset
data.tail(3)
# Out:
#        Country  Year      Status  Life expectancy (men)
# 2935  Zimbabwe  2002  Developing                     50  \
# 2936  Zimbabwe  2001  Developing                     66
# 2937  Zimbabwe  2000  Developing                     55
#
#       Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)
# 2935                      74                     55                       95  \
# 2936                      66                     74                       78
# 2937                      76                     76                       98
#
#       Infant deaths  Alcohol  Percentage expenditure  ...  Polio
# 2935             25     4.43                     0.0  ...   73.0  \
# 2936             25     1.72                     0.0  ...   76.0
# 2937             24     1.68                     0.0  ...   78.0
#
#       Total expenditure  Diphtheria   HIV/AIDS         GDP  Population
# 2935               6.53         71.0      39.8   57.348340    125525.0  \
# ...

# %%
# check null value
data.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy (men)                0
# Life expectancy(women)               0
# Adult Mortality (men)                0
# Adult Mortality (women)              0
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B(men)                     0
# Hepatitis B(women)                   0
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# ...

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy (men)              0
# Life expectancy(women)             0
# Adult Mortality (men)              0
# Adult Mortality (women)            0
# Infant deaths                      0
# Alcohol                            0
# Percentage expenditure             0
# Hepatitis B(men)                   0
# Hepatitis B(women)                 0
# Measles                            0
# BMI                                0
# Under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
data.groupby('Title')[ 'Runtime (Minutes)'].max().tail(10)

# %%
#shapeof our datasets(number of row and number of column)
print("Number of rows:",data.shape[0]);
print("Number of columns:",data.shape[1]);
# Out:
# Number of rows: 2938
# Number of columns: 25

# %%
#convert status into number
data['Status']=data['Status'].map({'Developed':0,'Developing':1})

# %%
data.head()
# Out:
#        Country  Year  Status  Life expectancy (men)  Life expectancy(women)
# 0  Afghanistan  2015       1                     70                      66  \
# 1  Afghanistan  2014       1                     59                      67
# 2  Afghanistan  2013       1                     79                      51
# 3  Afghanistan  2012       1                     65                      81
# 4  Afghanistan  2011       1                     76                      75
#
#    Adult Mortality (men)  Adult Mortality (women)  Infant deaths  Alcohol
# 0                     67                       65             62     0.01  \
# 1                     73                       85             64     0.01
# 2                     87                       67             66     0.01
# 3                     63                       91             69     0.01
# 4                     57                       72             71     0.01
#
# ...

# %%
# conver object into integer
data['Country']=pd.to_numeric(data['Country'],errors='coerce')

# %%
data['Status']=pd.to_numeric(data['Status'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          0 non-null      float64
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   int64
#  3   Life expectancy (men)            2938 non-null   int64
#  4   Life expectancy(women)           2938 non-null   int64
#  5   Adult Mortality (men)            2938 non-null   int64
#  6   Adult Mortality (women)          2938 non-null   int64
#  7   Infant deaths                    2938 non-null   int64
#  8   Alcohol                          2744 non-null   float64
#  9   Percentage expenditure           2938 non-null   float64
#  10  Hepatitis B(men)                 2938 non-null   int64
#  11  Hepatitis B(women)               2938 non-null   int64
# ...

# %%
average_status=data.groupby('Year')['Status'].max().sort_values(ascending=False).head(1)
average_status
# Out:
# Year
# 2000    1
# Name: Status, dtype: int64

# %%
data1.corr()
# Out:
#                                      Year  Life expectancy (men)
# Year                             1.000000               0.024007  \
# Life expectancy (men)            0.024007               1.000000
# Life expectancy(women)           0.019896               0.007592
# Adult Mortality (men)            0.027791              -0.043547
# Adult Mortality (women)         -0.007309              -0.015130
# Infant deaths                   -0.038117              -0.050412
# Alcohol                         -0.057403               0.023826
# Percentage expenditure           0.078824               0.041234
# Hepatitis B(men)                -0.040256               0.003558
# Hepatitis B(women)               0.016378               0.029902
# Measles                         -0.102856              -0.034661
# BMI                              0.087174               0.041265
# Under-five deaths               -0.042942              -0.052292
# ...

# %%
sns.heatmap(data1.corr(),cmap='viridis',cbar=True,yticklabels=False,annot=False)
plt.title('Corelation')
plt.show()

# %%
top_Infant_deaths=data.groupby('Country')['Infant deaths'].max().sort_values(ascending=False).head(5)
top_Infant_deaths
# Out:
# Country
# India       1800
# Nigeria      576
# China        490
# Pakistan     385
# Ethiopia     253
# Name: Infant deaths, dtype: int64

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy (men)
# 0  Afghanistan  2015  Developing                     70  \
# 1  Afghanistan  2014  Developing                     59
# 2  Afghanistan  2013  Developing                     79
# 3  Afghanistan  2012  Developing                     65
# 4  Afghanistan  2011  Developing                     76
#
#    Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)
# 0                      66                     67                       65  \
# 1                      67                     73                       85
# 2                      51                     87                       67
# 3                      81                     63                       91
# 4                      75                     57                       72
#
#    Infant deaths  Alcohol  Percentage expenditure  ...  Polio
# 0             62     0.01               71.279624  ...    6.0  \
# ...

# %%
x= data1.drop('Percentage expenditure', axis='columns')

# %%
y= data1['Percentage expenditure']

# %%
#splitting test set and training set
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len('x_train')
# Out:
# 7

# %%
x_train.count()
# Out:
# Year                               1675
# Life expectancy (men)              1675
# Life expectancy(women)             1675
# Adult Mortality (men)              1675
# Adult Mortality (women)            1675
# Infant deaths                      1675
# Alcohol                            1675
# Hepatitis B(men)                   1675
# Hepatitis B(women)                 1675
# Measles                            1675
# BMI                                1675
# Under-five deaths                  1675
# Polio                              1675
# Total expenditure                  1675
# Diphtheria                         1675
# HIV/AIDS                           1675
# GDP                                1675
# Population                         1675
# thinness  1-19 years               1675
# thinness 5-9 years                 1675
# Income composition of resources    1675
# Schooling                          1675
# dtype: int64

# %%
data.count()
# Out:
# Country                            2094
# Year                               2094
# Status                             2094
# Life expectancy (men)              2094
# Life expectancy(women)             2094
# Adult Mortality (men)              2094
# Adult Mortality (women)            2094
# Infant deaths                      2094
# Alcohol                            2094
# Percentage expenditure             2094
# Hepatitis B(men)                   2094
# Hepatitis B(women)                 2094
# Measles                            2094
# BMI                                2094
# Under-five deaths                  2094
# Polio                              2094
# Total expenditure                  2094
# Diphtheria                         2094
# HIV/AIDS                           2094
# GDP                                2094
# Population                         2094
# thinness  1-19 years               2094
# thinness 5-9 years                 2094
# ...

# %%
x_test.count()
# Out:
# Year                               419
# Life expectancy (men)              419
# Life expectancy(women)             419
# Adult Mortality (men)              419
# Adult Mortality (women)            419
# Infant deaths                      419
# Alcohol                            419
# Hepatitis B(men)                   419
# Hepatitis B(women)                 419
# Measles                            419
# BMI                                419
# Under-five deaths                  419
# Polio                              419
# Total expenditure                  419
# Diphtheria                         419
# HIV/AIDS                           419
# GDP                                419
# Population                         419
# thinness  1-19 years               419
# thinness 5-9 years                 419
# Income composition of resources    419
# Schooling                          419
# dtype: int64

# %%
y_test.count()
# Out:
# 419

# %%
y_train.count()
# Out:
# 1675

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR     #supervised learning algorith aka support vector machine
from sklearn.ensemble import RandomForestRegressor     
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()

# %%
 lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2094 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2094 non-null   object
#  1   Year                             2094 non-null   int64
#  2   Status                           2094 non-null   object
#  3   Life expectancy (men)            2094 non-null   int64
#  4   Life expectancy(women)           2094 non-null   int64
#  5   Adult Mortality (men)            2094 non-null   int64
#  6   Adult Mortality (women)          2094 non-null   int64
#  7   Infant deaths                    2094 non-null   int64
#  8   Alcohol                          2094 non-null   float64
#  9   Percentage expenditure           2094 non-null   float64
#  10  Hepatitis B(men)                 2094 non-null   int64
#  11  Hepatitis B(women)               2094 non-null   int64
# ...

# %%
data1= data.drop(['Country','Status'],axis='columns')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2094 entries, 0 to 2937
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             2094 non-null   int64
#  1   Life expectancy (men)            2094 non-null   int64
#  2   Life expectancy(women)           2094 non-null   int64
#  3   Adult Mortality (men)            2094 non-null   int64
#  4   Adult Mortality (women)          2094 non-null   int64
#  5   Infant deaths                    2094 non-null   int64
#  6   Alcohol                          2094 non-null   float64
#  7   Percentage expenditure           2094 non-null   float64
#  8   Hepatitis B(men)                 2094 non-null   int64
#  9   Hepatitis B(women)               2094 non-null   int64
#  10  Measles                          2094 non-null   int64
#  11  BMI                              2094 non-null   float64
# ...

# %%
svm=SVR()

# %%
svm.fit(x_train,y_train)
# Out:
# SVR()

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
gr=svm.fit(x_train,y_train)

# %%
gr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred1=lr.predict(x_test)

# %%
y_pred2=svm.predict(x_test)

# %%
y_pred3=rf.predict(x_test)

# %%
y_pred4=gr.predict(x_test)

# %%
df1=pd.DataFrame({'Actual':y_test,'Lr':y_pred1,'svm':y_pred2,'rf':y_pred3,'gr':y_pred4})

# %%
plt.subplot(221)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['Lr'].iloc[0:11],label="Lr")
plt.legend()


plt.subplot(222)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['svm'].iloc[0:11],label="svm")
plt.legend()

plt.subplot(223)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['rf'].iloc[0:11],label="rf")
plt.legend()

plt.subplot(224)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['gr'].iloc[0:11],label="gr")
plt.tight_layout()
plt.legend()

# %%
x_test.head()
# Out:
#       Year  Life expectancy (men)  Life expectancy(women)
# 2312  2000                     84                      64  \
# 1786  2009                     82                      71
# 1145  2008                     52                      68
# 388   2011                     57                      63
# 29    2002                     76                      85
#
#       Adult Mortality (men)  Adult Mortality (women)  Infant deaths  Alcohol
# 2312                     50                       76             29     3.97  \
# 1786                     64                       65             52     0.28
# 1145                     92                       74              4     3.14
# 388                      51                       63              1    10.67
# 29                       57                       55              1     3.73
#
#       Hepatitis B(men)  Hepatitis B(women)  Measles  ...  Polio
# 2312                41                  31     3575  ...   46.0  \
# ...

# %%
#metrics bata score nikaleko kun chai thik xa vanerw
score1= metrics.r2_score(y_test,y_pred1)
score2= metrics.r2_score(y_test,y_pred2)
score3= metrics.r2_score(y_test,y_pred3)
score4= metrics.r2_score(y_test,y_pred4)

# %%
print(score1, score2, score3, score4)
# Out:
# 0.8005394182094184 -0.12348143988117388 0.7910132946336393 -0.12348143988117388

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy (men)',
#        'Life expectancy(women)', 'Adult Mortality (men)',
#        'Adult Mortality (women)', 'Infant deaths', 'Alcohol',
#        'Percentage expenditure', 'Hepatitis B(men)', 'Hepatitis B(women)',
#        'Measles', 'BMI', 'Under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df=pd.DataFrame(x,index=[0])
df
# Out:
#    Year  Life expectancy (men)  Life expectancy(women)  Adult Mortality (men)
# 0  2015                     70                      66                     67  \
#
#    Adult Mortality (women)  Infant deaths  Alcohol  Hepatitis B(men)
# 0                       65             62     0.01                40  \
#
#    Hepatitis B(women)  Measles  ...  Polio  Total expenditure  Diphtheria
# 0                  40     1154  ...    6.0               8.16         65.0  \
#
#    HIV/AIDS        GDP  Population  thinness  1-19 years  thinness 5-9 years
# 0       0.1  584.25921  33736494.0                  17.2                17.3  \
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
#
# [1 rows x 22 columns]

# %%
new_pred=lr.predict(df)

# %%
print('the Percentage expenditure is',new_pred[0])
# Out:
# the Percentage expenditure is 63.22178458979397

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()
